# %%
import statistics as stat
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/StudentsPerformance.csv')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
#  **1)Find out how many males and females participated in the test.**

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# ***there are 518 female students and 482 male students***

# %% [markdown]
# **2)What do you think about the students' parental level of education?**

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# *some college* -**226**,
# *associate's degree* -**222**,
# *high school* -**196**,
# *some high school* -**179**,
# *bachelor's degree* -**118**,
# *master's degree* -**59**,

# %% [markdown]
# **3)Who scores the most on average for math, reading and writing based on**
#
# **1.**   **gender**
# **2.**   **Test preparation course**

# %%
total=data['math score']+ data['reading score'] + data['writing score']

# %%
data['average']=total/3

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.barplot(x=data['gender'],y=data['average'])
plt.subplot(1,2,2)
sns.barplot(x=data['test preparation course'],y=data['average'])

# %% [markdown]
# **Inference**
# >***1)based on gender***
#
# ***female scored more than male***
#
# >***2)based on test preparation course***
#
#
# ***those who completed the test preparation course scored more***

# %% [markdown]
# **4. What do you think about the scoring variation for math, reading and writing based on**
#
# **1.** **gender**
# **2.** **test preparation course**

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.barplot(x=data['gender'],y=data['math score'])
plt.subplot(1,3,2)
sns.barplot(x=data['gender'],y=data['reading score'])
plt.subplot(1,3,3)
sns.barplot(x=data['gender'],y=data['writing score'])

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.barplot(x=data['test preparation course'],y=data['math score'])
plt.subplot(1,3,2)
sns.barplot(x=data['test preparation course'],y=data['reading score'])
plt.subplot(1,3,3)
sns.barplot(x=data['test preparation course'],y=data['writing score'])

# %% [markdown]
# **inference:**
# >***based on gender***
# 1.  ***male candidates scored more in maths test***
# 2.  ***female candidates scored more in reading test***
# 3.  ***female candidates scored more in writing test***
# > ***based on test preparation course***
# 1.   ***those candidates who completed the test preparation course scored more in all the tests.***

# %% [markdown]
# **5.** **The management needs your help to give bonus points to the top 25% of
# students based on their math score, so how will you help the management to
# achieve this.**

# %%
df=data['math score'].sort_values(ascending=False)

# %% [markdown]
# ***25% of 1000=250***

# %%
pd.set_option("max_rows", None)
top_25_percent=df.head(250)

# %%
#top 25% students based on maths score
top_25_percent
# Out:
# 999    100
# 996    100
# 515    100
# 517    100
# 516    100
# 997    100
# 998    100
# 995     99
# 513     99
# 514     99
# 994     98
# 993     98
# 512     98
# 992     97
# 991     97
# 989     97
# 510     97
# 511     97
# 990     97
# 509     96
# 508     96
# 988     96
# 507     95
# 987     95
# 505     94
# 506     94
# 982     94
# 983     94
# 985     94
# 986     94
# 984     94
# 504     93
# 503     93
# 980     93
# 981     93
# 978     92
# 979     92
# 499     92
# 502     92
# 501     92
# 500     92
# 973     91
# 497     91
# 498     91
# 975     91
# 977     91
# 974     91
# 972     91
# 976     91
# 971     91
# 969     90
# 967     90
# 968     90
# 495     90
# 970     90
# 965     90
# 496     90
# 966     90
# 964     90
# 494     89
# 959     89
# 960     89
# 961     89
# 962     89
# 963     89
# 488     88
# 493     88
# 492     88
# 491     88
# 490     88
# 956     88
# 489     88
# 955     88
# 951     88
# 950     88
# 953     88
# ...

# %% [markdown]
# # **or**

# %%
df2=data[data['math score'] >= 75]

# %%
df3=df2.sort_values(by = 'math score',ascending=False)

# %%
df3.head(250)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 998    male        group E          associate's degree  free/reduced
# 997    male        group D                some college      standard
# 996    male        group A                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# 515  female        group E                some college      standard
# 995    male        group E                some college      standard
# 514  female        group E                 high school      standard
# 513  female        group E           bachelor's degree      standard
# 994    male        group C          associate's degree      standard
# 993    male        group C                some college      standard
# 512  female        group D                some college      standard
# ...

# %% [markdown]
# ***the above are the details of top 25% students based on their maths score***
